# %% [markdown]
# # Podatkovno rudarjenje 01 - evidenca nesreč na smučiščih
#
# #### avtor: Urban Papler
# #### datum: 27. 5. 2020

# %% [markdown]
# V tem notebooku bomo iz evidence nesreč na smučiščih izluščili nekaj zanimivih povezav in jih prikazali.

# %% [markdown]
# ### Korak 0: branje in priprava podatkov
#
# Preberemo podatke iz datoteke ter jih obdelamo tako, da bo delo z njimi čim lažje.

# %%
# priprava podatkov

import numpy as np                                     # knjižnica za obdelavo podatkov
import csv                                             # branje *.csv datotek
from collections import defaultdict                    # napredni slovar
import matplotlib                                      # knjižnica za risanje grafov
import matplotlib.pyplot as plt                        # graf
from scipy.stats import multivariate_normal as mvn     # izračun grafa iz porazdelitve
from Orange.data.filter import SameValue               # Orange
from Orange.data import Table                          # Orange ustvarjanje tabele
import time                                            # pretvorba datumov in časov
import datetime as dt                                  # računanje z datumi

# %% [markdown]
# Podatki so pridobljeni iz OPSI (Odprti podatki Slovenije), in sicer iz [Evidence nesreč na smučiščih](https://podatki.gov.si/dataset/evidenca-nesrec-na-smuciscih1 "Evidenca nesreč na smučiščih - OPSI").

# %% [markdown]
# Branje datoteke [2013_12_01-2017_03_09.csv](./podatki/2013_12_01-2017_03_09.csv) in ustvarjanje tabele **tab1**:

# %%
# branje datoteke 2013_12_01-2017_03_09.csv

tab1 = []
file = open("./podatki/2013_12_01-2017_03_09.csv", 'r', encoding='ANSI')
file.readline()
stevec = 0
for line in file:
    l = line.split(";")
    id = stevec
    stevec += 1
    str_id = l[0]
    # preverimo, če so podatki v vrstici zapisani v pravem formatu
    if len(l) != 23:
        print("Vrstica z ID = {:s} ima {:d} razčlenitev.".format(id, len(l)))
    # pripravimo podatke
    datum = l[1]
    if (len(datum) != 0):
        datum = time.strptime(datum, "%d.%m.%Y")
        datum = time.strftime("%Y-%m-%d", datum)
    cas = l[2]
    if (len(cas) != 0):
        cas = time.strptime(cas, "%H:%M")
        cas = time.strftime("%H-%M", cas)
    datum_in_cas = "{:s}_{:s}".format(datum, cas)
    nadzornik = (l[3].upper().find("DA") != -1)
    zdravnik = (l[4].upper().find("DA") != -1)
    resevalec = (l[5].upper().find("DA") != -1)
    A_leto = l[6]
    if (len(A_leto) != 0):
        A_leto = int(A_leto)
    else:
        A_leto = None
    A_drzava = l[7].upper().strip('"').replace("È", "Č")
    if A_drzava == " ":
        A_drzava = ""
    A_zvrst = l[8].upper()
    if len(A_zvrst) == 0:
        A_zvrst = 0
    elif "AL" in A_zvrst:
        A_zvrst = 1
    elif "DE" in A_zvrst:
        A_zvrst = 2
    elif "SAN" in A_zvrst:
        A_zvrst = 3
    else:
        A_zvrst = 4
    A_ravnanje = l[9]
    B_leto = l[10]
    if (len(B_leto) != 0):
        B_leto = int(B_leto)
    else:
        B_leto = None
    B_drzava = l[11].upper().replace("È", "Č")
    if B_drzava == " ":
        B_drzava = ""
    B_zvrst = l[12].upper()
    if len(B_zvrst) == 0:
        B_zvrst = 0
    elif "AL" in B_zvrst:
        B_zvrst = 1
    elif "DE" in B_zvrst:
        B_zvrst = 2
    elif "SAN" in B_zvrst:
        B_zvrst = 3
    else:
        B_zvrst = 4
    B_ravnanje = l[13]
    skica = (l[14].upper().find("DA") != -1)
    fotografija = (l[15].upper().find("DA") != -1)
    posnetek = (l[16].upper().find("DA") != -1)
    vreme = l[17]
    vidljivost = l[18]
    temperatura = l[19]
    sneg = l[20]
    veter = l[21]
    poskodba = l[22].strip("\n").strip('"')
    # indeksiramo poskodbe
    if (len(poskodba) != 0):
        #           lažja, hujša
        poskodba = { "L": 2, "H": 3}.get(poskodba[0], -1)
    else:
        poskodba = -1
    # shranimo podatke
    podatki = (id, str_id, datum, cas, datum_in_cas, nadzornik, zdravnik, resevalec,
               A_leto, A_drzava, A_zvrst, A_ravnanje,
               B_leto, B_drzava, B_zvrst, B_ravnanje,
               skica, fotografija, posnetek, vreme, vidljivost,
               temperatura, sneg, veter, poskodba)
    tab1.append(podatki)

# priprava tabele, ki bo olajšala dostop do podatkov
def t1g (*atributi):
    slovar_atributov = {"ID": 0, "STR_ID": 1, "STRING_ID": 1, "DATUM": 2, "CAS": 3,
                        "DATUM_IN_CAS": 4, "DATUM IN CAS": 4, "DC": 4,
                        "NADZORNIK": 5, "ZDRAVNIK": 6, "RESEVALEC": 7,
                        "A_LETO": 8, "A LETO": 8, "A_DRZAVA": 9, "A DRZAVA": 9,
                        "A_ZVRST": 10, "A ZVRST": 10, "A_RAVNANJE": 11, "A RAVNANJE": 11,
                        "B_LETO": 12, "B LETO": 12, "B_DRZAVA": 13, "B DRZAVA": 13,
                        "B_ZVRST": 14, "B ZVRST": 14, "B_RAVNANJE": 15, "B RAVNANJE": 15,
                        "SKICA": 16, "FOTOGRAFIJA": 17, "POSNETEK": 18, "VREME": 19,
                        "VIDLJIVOST": 20, "TEMPERATURA": 21, "SNEG": 22, "VETER": 23, "POSKODBA": 24}
    # ni vrednosti
    if (len(atributi) == 0):
        return
    # samo ena vrednost
    if (len(atributi) == 1):
        return slovar_atributov[atributi[0].upper()]
    return [slovar_atributov[atribut.upper()] for atribut in atributi]

# %% [markdown]
# Branje datoteke [2017_11_01-2019_04_02.csv](./podatki/2017_11_01-2019_04_02.csv) in ustvarjanje tabele **tab2**:

# %%
# funkcija za zamenjavo znakov v nizu
def replace_within (niz, najdi=';', zamenjaj='_', znotraj='"'):
    niz = list(niz)
    znotraj_niza = False
    znaki = len(niz)
    for i in range(znaki):
        if (niz[i] == znotraj):
            znotraj_niza = not znotraj_niza
        elif niz[i] == najdi and znotraj_niza:
            niz[i] = zamenjaj
    return "".join(niz)

# %%
# branje datoteke 2017_11_01-2019_04_02.csv

tab2 = []
file = open("./podatki/2017_11_01-2019_04_02.csv", 'r', encoding='ANSI')
file.readline()
stevec = 0
for line in file:
    # zamenjamo podpičja (;) v narekovajih (") z podčrtajem (_), da se bo niz pravilno razčlenil
    line = replace_within(line, najdi=';', zamenjaj='_', znotraj='"')
    l = line.split(";")
    id = stevec
    stevec += 1
    # preverimo, če so podatki v vrstici zapisani v pravem formatu
    if len(l) != 16:
        print("Vrstica z ID = {:d} ima {:d} razčlenitev.".format(id, len(l)))
    # pripravimo podatke
    smucisce = l[0].split("_")[0].strip('"')
    upravljalec = l[1].split("_")[0].strip('"')
    drzava = l[2].split("_")[0].upper().strip('"').replace("È", "Č")
    if drzava == " ":
        drzava = ""
    if len(l[3]) == 0:
        # vrstica je verjetno prazna
        #print("Vstica {:s} je verjetno prazna.".format(line.strip("\n")))
        stevec -= 1
        continue
    spol = l[3].strip('"')[0]
    if spol == " ":
        spol = ""
    #zvrst = l[4]
    datum = l[5]
    if (len(datum) != 0):
        datum = time.strptime(datum, "%d.%m.%Y")
        datum = time.strftime("%Y-%m-%d", datum)
    cas = l[6]
    if (len(cas) != 0):
        cas = time.strptime(cas, "%H:%M")
        cas = time.strftime("%H-%M", cas)
    datum_in_cas = "{:s}_{:s}".format(datum, cas)
    kraj = l[7].split("_")[0].strip('"')
    vreme = l[8].split("_")[0].strip('"')
    zvrst = l[9].split("_")[0].strip('"').upper()
    if len(zvrst) == 0:
        zvrst = 0
    elif "SMU" in zvrst:
        zvrst = 1
    elif "DE" in zvrst:
        zvrst = 2
    elif "SAN" in zvrst:
        zvrst = 3
    else:
        zvrst = 4
    ravnanje = l[10].split("_")[0].strip('"')
    incident = l[11].split("_")[0].strip('"')
    poskodba = l[12].strip('"').split("_")[0].strip('"')
    # indeksiramo poskodbe
    if (len(poskodba) != 0):
        #           brez, lažja, hujša, posebno huda, smrt, materialna
        poskodba = {"B": 1, "L": 2, "H": 3, "P": 4, "S": 5, "M": 6}.get(poskodba[0], -1)
    else:
        poskodba = -1
    vrsta_poskodbe = l[13].split("_")[0].strip('"')
    lokacija_poskodbe = l[14].split("_")[0].strip('"')
    financno = l[15].strip("\n").split("_")[0].strip('"')
    # shranimo podatke
    podatki = (id, datum, cas, datum_in_cas, kraj, drzava, zvrst, ravnanje, incident,
               poskodba, vrsta_poskodbe, lokacija_poskodbe, financno, vreme,
              spol, smucisce, upravljalec)
    tab2.append(podatki)

# priprava tabele, ki bo olajšala dostop do podatkov
def t2g (*atributi):
    slovar_atributov = {"ID": 0, "DATUM": 1, "CAS": 2, "DATUM_IN_CAS": 3, "DATUM IN CAS": 3, "DC": 3, 
                       "KRAJ": 4, "DRZAVA": 5, "ZVRST": 6, "RAVNANJE": 7, "INCIDENT": 8,
                       "POSKODBA": 9, "VRSTA_POSKODBE": 10, "VRSTA POSKODBE": 10, "VRSTA": 10,
                       "LOKACIJA_POSKODBE": 11, "LOKACIJA POSKODBE": 11, "LOKACIJA": 11,
                       "FINANCNO": 12, "FINANCE": 12, "MATERIALNO": 12, "MATERIAL": 12,
                       "VREME": 13, "SPOL": 14, "SMUCISCE": 15, "UPRAVLJALEC": 16}
    # ni vrednosti
    if (len(atributi) == 0):
        return
    # samo ena vrednost
    if (len(atributi) == 1):
        return slovar_atributov[atributi[0].upper()]
    return [slovar_atributov[atribut.upper()] for atribut in atributi]

# %% [markdown]
# Ustvarimo skupno tabelo **tab** (tabeli tab1 in tab2 združimo, kjer lahko):

# %%
# skupna tabela
tab = []
stevec = 0

atributi1 = ["DATUM", "CAS", "DATUM IN CAS", "A DRZAVA", "A ZVRST", "A RAVNANJE", "VREME", "POSKODBA"]
atributi2 = ["DATUM", "CAS", "DATUM IN CAS",   "DRZAVA",   "ZVRST",   "RAVNANJE", "VREME", "POSKODBA"]

# prepišemo tab1:
for indeks, vnos in enumerate(tab1):
    # tab id, tabela, tab1 id
    ids = [stevec, 1, indeks]
    stevec += 1
    podatki = [vnos[vrednost] for vrednost in t1g(*atributi1)]
    podatki = tuple(ids + podatki)
    tab.append(podatki)

# prepišemo tab2:
for indeks, vnos in enumerate(tab2):
    # tab id, tabela, tab1 id
    ids = [stevec, 2, indeks]
    stevec += 1
    podatki = [vnos[vrednost] for vrednost in t2g(*atributi2)]
    podatki = tuple(ids + podatki)
    tab.append(podatki)

# priprava tabele, ki bo olajšala dostop do podatkov
def tg (*atributi):
    slovar_atributov = {"ID": 0, "TABELA": 1, "TAB": 1, "T": 1, "TID": 2, "TAB_ID": 2, "TAB ID": 2,
                       "DATUM": 3, "CAS": 4, "DATUM_IN_CAS": 5, "DATUM IN CAS": 5, "DC": 5,
                       "DRZAVA": 6, "ZVRST": 7, "RAVNANJE": 8, "VREME": 9, "POSKODBA": 10}
    # ni vrednosti
    if (len(atributi) == 0):
        return
    # samo ena vrednost
    if (len(atributi) == 1):
        return slovar_atributov[atributi[0].upper()]
    return [slovar_atributov[atribut.upper()] for atribut in atributi]

# %%
# datumi:
tab1_start = dt.date(2013, 12,  1)
tab1_end   = dt.date(2017,  3,  9)
tab2_start = dt.date(2017, 11,  1)
tab2_end   = dt.date(2019,  4,  2)

day_diff1 = (tab1_end - tab1_start).days
day_diff2 = (tab2_end - tab2_start).days
day_diff  = day_diff1 + day_diff2


# pretvorba datumov
def datum_pretvorba (datum):
    format_hr = "%d. %m. %Y"
    format_pr = "%Y-%m-%d"
    if datum.index("-") != -1:
        # datum je v "human readable" formatu
        return time.strftime(format_hr, time.strptime(datum, format_pr))
    # datum je v "programerskem" formatu
    return time.strftime(format_pr, time.strptime(datum, format_hr))
print("Prva tabela je beležila {:d} dni, druga pa {:d} dni (skupaj {:d} dni).".format(day_diff1, day_diff2, day_diff))
# Out:
# Prva tabela je beležila 1194 dni, druga pa 517 dni (skupaj 1711 dni).

# %% [markdown]
# Pripravimo nekaj uporabnih tabel, ki mapirajo indekse v nize:

# %%
# mapiranje indeksov poškodb:
map_poskodbe = ["ni podatka", "brez", "lažja", "hujša", "posebno huda", "smrt", "materialna škoda"]

# mapiranje zvrsti:
map_zvrst = ["ni podatka", "smučanje", "deskanje", "sankanje", "drugo"]

# %% [markdown]
# ### Korak 1: nekaj osnovnih statistik
#
# Iz podatkov izluščimo nekaj osnovnih statistik o zabeleženih poškodbah na smučiščih:

# %%
# preštejemo vse zabeležene incidente
total1 = len(tab1) # število vnosov v tabeli 1
total2 = len(tab2) # število vnosov v tabeli 2
total  = len(tab)  # število vnosov v skupni tabeli
print("Zabeleženih je bilo {:d} nesreč na smučiščih ({:d} v prvi in {:d} v drugi tabeli).\n".format(total, total1, total2))

# čas beleženja
print("Beleženje je potekalo {:d} dni ({:d} dni v prvo in {:d} dni v drugo tabelo).\n".format(day_diff, day_diff1, day_diff2))

# povprečje incidentov
print("V povprečju je bilo na dan zabeleženih {:.2f} nesreč ({:.2f} v prvem in {:.2f} v drugem obdobju).\n"
      .format(total / day_diff, total1 / day_diff1, total2 / day_diff2))

# največ nesreč na dan
nesrece_gostota = defaultdict(None)
for vnos in tab:
    datum_indeks = tg("DATUM")
    datum = vnos[datum_indeks]
    vrednost = nesrece_gostota.get(datum, 0)
    nesrece_gostota[datum] = vrednost + 1
nesrece_gostota = sorted([(val, key) for key, val in nesrece_gostota.items()], reverse=True)
print("Največ nesreč je bilo zabeleženih dne {:s}, in sicer {:d}, zelo blizu pa je dan {:s} z {:d} zabeleženimi nezgodami.\n"
.format(datum_pretvorba(nesrece_gostota[0][1]), nesrece_gostota[0][0],
        datum_pretvorba(nesrece_gostota[1][1]), nesrece_gostota[1][0]))

# resnost poškodbe
poskodba, stevilo = np.unique([map_poskodbe[tab[i][tg("POSKODBA")]] for i in range(total)], return_counts=True)
poskodbe = dict(zip(poskodba, stevilo))
print("Število in delež poškodb glede na resnost poškodbe:\n{:>16s} {:>5s} {:>8s}".format("resnost", "n", "delež"))
for stevilo, poskodba in sorted([(stevilo, poskodba) for poskodba, stevilo in poskodbe.items()], reverse=True):
    print("{:>16s}: {:4d} ({:5.2f}%)".format(poskodba, stevilo, 100 * stevilo / total))
# Out:
# Zabeleženih je bilo 5257 nesreč na smučiščih (3364 v prvi in 1893 v drugi tabeli).
#
# Beleženje je potekalo 1711 dni (1194 dni v prvo in 517 dni v drugo tabelo).
#
# V povprečju je bilo na dan zabeleženih 3.07 nesreč (2.82 v prvem in 3.66 v drugem obdobju).
#
# Največ nesreč je bilo zabeleženih dne 19. 02. 2015, in sicer 33, zelo blizu pa je dan 17. 02. 2015 z 31 zabeleženimi nezgodami.
#
# Število in delež poškodb glede na resnost poškodbe:
#          resnost     n    delež
#            lažja: 4873 (92.70%)
#            hujša:  292 ( 5.55%)
#             brez:   86 ( 1.64%)
# materialna škoda:    3 ( 0.06%)
#             smrt:    2 ( 0.04%)
#     posebno huda:    1 ( 0.02%)

# %% [markdown]
# ### Korak 2: starost ponesrečencev
#
# Izračunamo in prikažemo nekaj zanimivih statistik glede na starost ponesrečencev.

# %%
# tabela starosti ponesrečencev
tab_starost = []
for vnos in tab1:
    leto_rojstva = vnos[t1g("A LETO")]
    # preverimo, če imamo podatek o letu rojstva
    if leto_rojstva == None:
        continue
    leto_nesrece = vnos[t1g("DATUM")]
    # preverimo, če imamo podatek o letu nesreče
    if len(leto_nesrece) < 1:
        continue
    leto_nesrece = int(leto_nesrece[:4])
    starost = leto_nesrece - leto_rojstva
    podatki = (starost, *vnos)
    tab_starost.append(podatki)
# razvrstimo po starosti
tab_starost = sorted(tab_starost)

# razdelimo na starostne skupine
starost_unique, starost_count = np.unique([(tab_starost[i][0] // 10) * 10 for i in range(len(tab_starost))], return_counts=True)
tab_starost_unique = dict(zip(starost_unique, starost_count))
# odstranimo nesmiselne podatke
tab_starost_unique.pop( 920, None)
tab_starost_unique.pop(1010, None)
tab_starost_unique.pop(1030, None)
print("Število ponesrečencev glede na starost:")
for starost, stevilo in tab_starost_unique.items():
    print("{:2d}-{:2d}: {:4d}".format(starost, starost + 9, stevilo))

# ustvarimo in prikažemo še histogram
tab_starost_2d = [[0]*9 for i in range(4)]
for vnos in tab_starost:
    zvrst = vnos[t1g("A ZVRST") + 1]
    if zvrst == 4 or zvrst == 3:
        zvrst = 0
    starost = vnos[0] // 10
    if starost >= 90:
        continue
    tab_starost_2d[zvrst][starost] += 1


# histogram
fig, axis = plt.subplots(figsize=(10, 8))
fig.suptitle("Porazdelitve zabeleženih nesreč glede na starost in zvrst", fontsize=16)

colors_main = ["#F43329", "#3F51F4", "#96E047"]

x_coords = [x for x in range(9)]
a0 = axis.bar(x_coords, tab_starost_2d[0], edgecolor='k', width=1, color=colors_main[2],
              tick_label=["{:d}-{:d}".format(10*x, (10*x)+9) for x in range(9)])
a1 = axis.bar(x_coords, tab_starost_2d[1], bottom=tab_starost_2d[0], edgecolor='k', width=1, color=colors_main[1])
a2 = axis.bar(x_coords, tab_starost_2d[2], color=colors_main[0], 
              bottom=[tab_starost_2d[0][x] + tab_starost_2d[1][x] for x in range(9)], edgecolor='k', width=1)
axis.legend([a2[0], a1[0], a0[0]],
            [map_zvrst[2], map_zvrst[1], map_zvrst[0] + "/" + map_zvrst[4]], fontsize=12)
plt.ylim(0, 1250)
plt.xlabel("Starostne skupine", fontsize=12)
plt.ylabel("Število ponesrečencev", fontsize=12)
plt.xlim(-0.5, 8.5);
# Out:
# Število ponesrečencev glede na starost:
#  0- 9:  367
# 10-19: 1189
# 20-29:  406
# 30-39:  368
# 40-49:  432
# 50-59:  277
# 60-69:  205
# 70-79:   71
# 80-89:   14

# %% [markdown]
# Kot vidimo, je bilo največ ponesrečencev v starostni skupini med 10 in 19 let. Ostale starostne skupine (od 0 do 49 let) so v statistiki nesreč enakomerno zastopane, po 50. letu pa začnejo števila poškodovancev padati (verjetno zaradi manjše udeležbe na smučanjih in na splošno manjšega števila starejših prebivalcev).
#
# Zanimivo je tudi slediti deležu zvrsti uživanja na snegu (smučanje in deskanje). Kot vidimo, je deskanje relativno popularno med osebami, starimi 10-30 let, pri naslednji starostni skupini pa delež deskarjev že začne padati. Deskarji, starejši od 40 let, skoraj niso več zastopani v statistiki nesreč (predvideno zaradi manjšega števila deskarjev te starosti).

# %%
tab_starost_n = tab_starost_2d[:-1]
# izračun deležev
totals = [0] * 9
for line in tab_starost_n:
    for i, entry in enumerate(line):
        totals[i] += entry

tab_starost_norm = [[0] * 9 for _ in range(3)]
for a, age_grp in enumerate(tab_starost_n):
    for e, entry in enumerate(age_grp):
        tab_starost_norm[a][e] = tab_starost_n[a][e] / sum([tab_starost_n[x][e] for x in range(3)])

totals_norm = [x / sum(totals) for x in totals]

totals_cumul = [0]
for x in totals_norm:
    totals_cumul.append(x + totals_cumul[-1])


# histogram
fig, axis = plt.subplots(figsize=(10, 8))
fig.suptitle("Porazdelitve zabeleženih nesreč glede na starost in zvrst", fontsize=16)

colors_main = ["#F43329", "#3F51F4", "#96E047"]

x_coords = [x for x in range(9)]

bottoms = []
for x in range(3):
    b = []
    for y, _ in enumerate(tab_starost_norm[0]):
        b.append(sum([tab_starost_norm[t][y] for t in range(x)]))
    bottoms.append(b)

# izris na graf
ax = []
for x in range(3):
    a = axis.bar(totals_cumul[:-1], tab_starost_norm[x], edgecolor='k',
                 width=totals_norm, align='edge', color=colors_main[2-x], bottom=bottoms[x])
    ax.append(a)

axis.legend([ax[2-x][0] for x in range(3)], [map_zvrst[2], map_zvrst[1], map_zvrst[0] + "/" + map_zvrst[4]], fontsize=12, loc=5)


xticks_locations = [(totals_cumul[x] + totals_cumul[x+1]) / 2 for x in range(len(totals_cumul) - 1)]
axis.set_xticks(totals_cumul)
axis.set_xticklabels('')
axis.set_xticks(xticks_locations, minor=True)
axis.set_xticklabels(["{:d}-{:d}".format(x, x+9) for x in range(0, 70, 10)], minor=True)
axis.tick_params(axis=u'both', which=u'minor',length=0)
axis.tick_params(axis=u'both', which=u'major',length=6)
y_ticks = [x / 100 for x in range(0, 101, 10)]
axis.set_yticks(y_ticks)
axis.set_yticklabels("{:.0f}%".format(100 * x) for x in y_ticks)
axis.grid(which='major', axis='y', color='k', lw=1.0, alpha=0.12)

plt.ylim(0, 1)
plt.xlabel("Starostne skupine", fontsize=12)
plt.ylabel("Delež ponesrečencev", fontsize=12)
plt.xlim(0, 1);

# %% [markdown]
# ### Korak 3: spol ponesrečencev
#
# Kakšno vlogo igra spol pri številu zabeleženih ponesrečencev? Kakšna je distribucija zvrsti glede na spol?

# %%
# število ponesrečencev glede na spol

tab_spol_2d = [[0]*2 for i in range(3)]
for vnos in tab2:
    spol = vnos[t2g("SPOL")]
    zvrst = vnos[t2g("ZVRST")]
    if zvrst == 3 or zvrst == 4:
        zvrst = 0
    spol = {"M": 0, "Ž": 1}.get(spol, 2)
    if spol == 2:
        continue
    tab_spol_2d[zvrst][spol] += 1
moski  = sum([x[0] for x in tab_spol_2d])
zenske = sum([x[1] for x in tab_spol_2d])
mz = moski + zenske
moski_p = moski / mz
zenske_p = zenske / mz

# izpis
print("Število ponesrečencev glede na spol:")
print("   ženske: {:4d}".format(zenske))
print("    moški: {:4d}".format(moski))


# ustvarimo in prikažemo histogram
fig, axis = plt.subplots(figsize=(7, 8))
fig.suptitle("Porazdelitve zabeleženih nesreč glede na spol in zvrst", fontsize=16)

colors_dark   = ["#CD2B22", "#3544CD", "#7EBC3B"]
colors_bright = ["#F5534A", "#5D6CF5", "#A6E463"]

x_coords = [zenske_p*0.5, zenske_p + moski_p*0.5]
spol_1 = [tab_spol_2d[0][1] / zenske, tab_spol_2d[0][0] / moski]
spol_2 = [tab_spol_2d[1][1] / zenske, tab_spol_2d[1][0] / moski]
spol_3 = [tab_spol_2d[2][1] / zenske, tab_spol_2d[2][0] / moski]
spol_2_c = [spol_1[0] + spol_2[0], spol_1[1] + spol_2[1]]

a0 = axis.bar(x_coords, spol_1, edgecolor='k', width=[zenske_p, moski_p],
              tick_label=["ženske", "moški"], color=[colors_bright[2], colors_dark[2]])
a1 = axis.bar(x_coords, spol_2, bottom=spol_1  , edgecolor='k', width=[zenske_p, moski_p],
             color=[colors_bright[1], colors_dark[1]])
a2 = axis.bar(x_coords, spol_3, bottom=spol_2_c, edgecolor='k', width=[zenske_p, moski_p],
             color=[colors_bright[0], colors_dark[0]])
legenda = [matplotlib.patches.Patch(facecolor=colors_main[0], edgecolor='k', label=map_zvrst[2]),
           matplotlib.patches.Patch(facecolor=colors_main[1], edgecolor='k', label=map_zvrst[1]),
           matplotlib.patches.Patch(facecolor=colors_main[2], edgecolor='k', label=(map_zvrst[0]+"/"+map_zvrst[4]))]
axis.legend(handles=legenda, fontsize=12, loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylim(0, 1)
plt.xlabel("Spol", fontsize=12)
plt.ylabel("Zvrsti (delež)", fontsize=12)
plt.xlim(0, zenske_p + moski_p);
# Out:
# Število ponesrečencev glede na spol:
#    ženske:  933
#     moški:  959

# %% [markdown]
# Vidimo, da sta oba spola približno enako zastopana v statistiki nesreč - žensk skupaj 933, moških pa 959. Pri tem je sicer treba povedati, da se za ta izračun uporablja le ena od dveh tabel (n = 1893), saj le ta tabela beleži spole poškodovancev.
#
# Na grafu je zastopanje vsake podskupine predstavljena s ploščino. Vidimo, da je več poškodovanih moških deskarjev kot pa žensk. Seveda pa to ne odgovori na vprašanje, ali so moški deskarji bolj podvrženi nesrečam ali pa je moških deskarjev le več (mogoče je pa tudi oboje res).

# %% [markdown]
# ### Korak 4: časovna razčlenitev
#
# Kakšna je pogostost nesreč skozi čas?

# %%
# priprava slovarjev

# glede na dan v letu
mesec_dan_map = [0, 31, 59, 90, 120, 151, 181, 212, 243, 273, 304, 334]
mesec_dan_num = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
def mesec_in_dan_v_dan(mesec, dan):
    return mesec_dan_map[mesec - 1] + dan

day_in_year_dict = defaultdict(int)
indeks_datum = tg("datum")
for vrednosti in tab:
    datum = vrednosti[indeks_datum]
    if len(datum) != 10:
        continue
    dan = int(datum[8:10])
    mesec = int(datum[5:7])
    if mesec == 2 and dan == 29:
        pass
    d = mesec_in_dan_v_dan(mesec, dan)
    day_in_year_dict[d] += 1

day_in_year = [0] * 365
for key, value in day_in_year_dict.items():
    day_in_year[key - 1] = value

# glede na dan v tednu
def date_to_weekday (datum):
    dan = int(datum[8:10])
    mesec = int(datum[5:7])
    leto = int(datum[0:4])
    d = mesec_in_dan_v_dan(mesec, dan)
    l = (leto - 1900) % 28
    d_t = (5 + (l % 7) + (l // 4) + (1, 0)[l % 4 == 0] + d + (0, 1)[leto % 4 == 0 and mesec >= 3]) % 7
    return d_t

dan_v_tednu = ["ponedeljek", "torek", "sreda", "četrtek", "petek", "sobota", "nedelja"]

day_in_week = [0] * 7
for vrednosti in tab:
    datum = vrednosti[indeks_datum]
    if len(datum) != 10:
        continue
    day_in_week[date_to_weekday(datum)] += 1

day_in_week_norm = [x / sum(day_in_week) for x in day_in_week]
day_in_week_percent = [100 * x for x in day_in_week_norm]

# glede na uro v dnevu
indeks_cas = tg("cas")
hour_in_day = [0] * 48
for vrednosti in tab:
    cas = vrednosti[indeks_cas]
    if len(cas) != 5:
        continue
    ure = int(cas[0:2])
    minute = int(cas[3:5])
    u = ure * 2 + (0, 1)[minute >= 30]
    hour_in_day [u] += 1

hour_in_day_norm = [x / sum(hour_in_day) for x in hour_in_day]
hour_in_day_percent = [100 * x for x in hour_in_day_norm]

# glede na mesec in leto
year_min = min([int(x[indeks_datum][0:4]) for x in tab])
year_max = max([int(x[indeks_datum][0:4]) for x in tab])

year_num = year_max - year_min + 1
accs_in_month = []
for i in range(year_num):
    accs_in_month.append([0] * 12)

for vrednosti in tab:
    datum = vrednosti[indeks_datum]
    if len(datum) != 10:
        continue
    mesec = int(datum[5:7])
    leto = int(datum[0:4])
    if not (0 < mesec < 13 or leto != null):
        continue
    accs_in_month[leto - year_min][mesec - 1] += 1

accs_in_month_norm = [[mnth / mesec_dan_num[n] for n, mnth in enumerate(yr)] for yr in accs_in_month]

# %% [markdown]
# #### 4.1: Graf nesreč glede na dan v letu

# %%
# graf nesreč glede na dan v letu

mesec_imena_map = ['Januar', 'Februar', 'Marec', 'April', 'Maj', 'Junij', 'Julij', 'Avgust', 'September', 'Oktober', 'November', 'December']

# histogram
fig, axis = plt.subplots(figsize=(16, 7))
fig.suptitle("Nesreče glede na dan v letu", fontsize=16)

y_lim = 129
y_ticks = [x for x in range(0, y_lim + 1, 25)]

xticks_locations = []
for i, value in enumerate((mesec_dan_map + [365])[1:]):
    xticks_locations.append((value + mesec_dan_map[i]) / 2)

x_coords = [x for x in range(365)]
axis.bar(x_coords, day_in_year, width=1, color="#2B3DE2", align='edge')

axis.set_xticks(mesec_dan_map + [365])
axis.set_xticklabels('')
axis.set_xticks(xticks_locations, minor=True)
axis.set_xticklabels(mesec_imena_map, minor=True)
axis.tick_params(axis=u'both', which=u'minor',length=0)
axis.tick_params(axis=u'both', which=u'major',length=6)
axis.set_yticks(y_ticks)
axis.grid(which='major', axis='y', color='k', lw=1.0, alpha=0.12)

for x in mesec_dan_map[1:]:
    axis.plot([x, x], [0, y_lim], color='k', alpha=0.7, lw=1.0, ls='--')

plt.ylim(0, y_lim)
plt.xlim(0, 365)
plt.ylabel("Število ponesrečencev", fontsize=12);

# %% [markdown]
# Na grafu vidimo razporeditev nesreč glede na datum (dan v letu). Lahko rečemo, da podatki verjetno v veliki večini korelirajo s pogostostjo obiskovanja smučišč. Največ poškodb je nekje v sredini februarja, v bolj toplejših mesecih pa poškodb praktično ni - je pa vseeno par nesreč zabeleženih tudi poleti.

# %% [markdown]
# #### 4.2: Graf nesreč glede na dan v tednu

# %%
# graf nesreč glede na dan v tednu

# histogram
fig, axis = plt.subplots(figsize=(11, 8))
fig.suptitle("Nesreče glede na dan v tednu", fontsize=16)

y_lim = 19.5
y_ticks = [x for x in range(0, 20, 2)]

x_coords = [x for x in range(7)]
c1 = "#8CC54E"
c2 = "#75A341"
colors = [c1, c1, c1, c1, c1, c2, c2]
axis.bar(x_coords, day_in_week_percent, width=1, color=colors, align='edge', edgecolor='k')

axis.set_xticks(range(8))
axis.set_xticklabels('')
axis.set_xticks([x + 0.5 for x in range(7)], minor=True)
axis.set_xticklabels(dan_v_tednu, minor=True, fontsize=13)
axis.tick_params(axis=u'both', which=u'minor',length=0)
axis.tick_params(axis=u'both', which=u'major',length=6)
axis.set_yticks(y_ticks)
axis.set_yticklabels(str(x) + '%' for x in y_ticks)
axis.grid(which='major', axis='y', color='k', lw=1.0, alpha=0.15)

for x in mesec_dan_map[1:]:
    axis.plot([x, x], [0, y_lim], color='k', alpha=0.7, lw=1.0, ls='--')

plt.ylim(0, y_lim)
plt.xlim(0, 7)
plt.ylabel("Delež ponesrečencev na določen dan", fontsize=12);

# %% [markdown]
# Izgleda je najvarnejši mesec za smučanje ponedeljek, čez teden pa število poškodb narašča. Najbolj nevarno je v soboto (verjetno tudi zaradi večjega števila smučarjev), kjer je število poškodb skoraj dvakrat večje od števila ponedeljkovih poškodb - približno 19% proti 10%.

# %% [markdown]
# #### 4.3: Graf nesreč glede na uro v dnevu

# %%
# graf nesreč glede na uro v dnevu

# histogram
fig, axis = plt.subplots(figsize=(14, 7))
fig.suptitle("Nesreče glede na uro v dnevu", fontsize=16)

y_lim = 11.5
y_ticks = [x for x in range(0, 12, 1)]

x_coords = [x / 2 for x in range(48)]
c1 = "#A00916"
c2 = "#D81E17"
colors = [c1, c2]
axis.bar(x_coords, hour_in_day_percent, width=0.5, color=colors, align='edge', edgecolor='k')

axis.set_xticks(range(24))
axis.set_xticklabels('')
axis.set_xticks([x + 0.5 for x in range(24)], minor=True)
axis.set_xticklabels([str(x) + ':XX' for x in range(24)], minor=True, fontsize=9)
axis.tick_params(axis=u'both', which=u'minor',length=0)
axis.tick_params(axis=u'both', which=u'major',length=6)
axis.set_yticks(y_ticks)
axis.set_yticklabels(str(x) + '%' for x in y_ticks)
axis.grid(which='major', axis='y', color='k', lw=1.0, alpha=0.1)

for x in range(25):
    axis.plot([x, x], [0, y_lim], color='k', alpha=0.7, lw=1.0, ls='--')

plt.ylim(0, y_lim)
plt.xlim(0, 24)
plt.ylabel("Delež ponesrečencev na časovni interval", fontsize=12);

# %% [markdown]
# V nočnih urah poškodb skoraj ni - verjetno so smučišča takrat zaprta, a si še vseeno kdo odloči privoščiti nočno smučanje.
#
# Pogostost poškodb začne naraščevati od devetih zjutraj pa nekje do enajstih, kjer so nesreče najbolj številčne. Zatem pa nesreče začnejo spet padati do nekje četrte ure popoldan, kjer se v zimskih mesecih po večini že stemni. V urah od šestih do enajstih zvečer se pogostost nesreč spet malo poveča - verjetno je za to spet odgovorna zmanjšana vidljivost.

# %% [markdown]
# #### 4.4: Graf nesreč glede na mesec in leto

# %%
# graf nesreč glede na mesec in leto

# histogram
fig, axis = plt.subplots(figsize=(16, 7))
fig.suptitle("Nesreče glede na mesec v določenem letu", fontsize=16)

y_lim = 17
y_ticks = [x for x in range(0, 17, 2)]

offset = 0.5 / (year_num + 1)
def get_x_coords (num, offset):
    return [x + offset for x in range(num)]
#axis.bar(x_coords, day_in_year, width=1, color="#2B3DE2", align='edge')

colors = ["#BF2520", "#3C49C1", "#8CC54E", "#BC4E65", "#406835", "#D86936", "#7D3ABC"]

for i in range(year_num):
    current_year = year_min + i
    axis.bar(get_x_coords(12, (2*i+1) * offset), accs_in_month_norm[i], width=2*offset, align='edge', edgecolor='k', color=colors[i])

axis.set_xticks(range(13))
axis.set_xticklabels('')
axis.set_xticks([x + 0.5 for x in range(12)], minor=True)
axis.set_xticklabels(mesec_imena_map, minor=True)
axis.tick_params(axis=u'both', which=u'minor',length=0)
axis.tick_params(axis=u'both', which=u'major',length=6)
axis.set_yticks(y_ticks)
axis.grid(which='major', axis='y', color='k', lw=1.0, alpha=0.12)

for x in mesec_dan_map[1:]:
    axis.plot([x, x], [0, y_lim], color='k', alpha=0.7, lw=1.0, ls='--')

legenda = [matplotlib.patches.Patch(facecolor=colors[i], edgecolor='k', label=str(year_min + i)) for i in range(year_num)]
axis.legend(handles=legenda, fontsize=12)

plt.ylim(0, y_lim)
plt.xlim(0, 12)
plt.ylabel("Delež ponesrečencev na mesec v letu", fontsize=12);

# %% [markdown]
# Tu si lahko ogledamo še pogostost nesreč posameznih let glede na mesec.
#
# Opazimo lahko, da nekateri meseci izstopajo od povprečja - Februar 2015 in Februar 2019 sta imela bistveno več nesreč kot pa druga leta v istem obdobju, leta 2014 pa sta bila Januar in December dokaj bolj varna v primerjavi z drugimi leti.

# %% [markdown]
# ### Korak 5: deleži in porazdelitve različnih atributov
#
# V tem delu si poglejmo, kakšne so porazdelitve različnih atributov (država, smučišče, vidljivost ...)

# %%
# priprava podatkov

# država ponesrečencev
dict_country = defaultdict(int)
for entry in tab:
    drzava = entry[tg("drzava")]
    if len(drzava) < 1:
        continue
    dict_country[drzava] += 1
# združimo države, ki imajo več različnih zapisov
countries_join = [("ZDRUŽENO KRALJESTVO", "ANGLIJA"), ("ZDRUŽENO KRALJESTVO VELIKA BRITANIJA", "ANGLIJA"), ("BIH", "BOSNA IN HERCEGOVINA")]
for c_from, c_to in countries_join:
    dict_country[c_to] += dict_country.get(c_from, 0)
    dict_country.pop(c_from, None)
# pretvorimo v seznam
countries = sorted([(num, country) for country, num in dict_country.items()], reverse=True)
countries = [(a, b) for b, a in countries]
# stisnjeni (condensed) podatki (za prikaz)
threshold_cond = 15
countries_cond = [x for x in countries[:min(threshold_cond, len(countries))]]
countries_others = 0
for x in range(threshold_cond, len(countries), 1):
    countries_others += countries[x][1]
countries_cond.append(("NI PODATKA / DRUGO", countries_others))

# %%
# graf držav ponesrečencev

fig, axis = plt.subplots(figsize=(13, 9))
fig.canvas.set_window_title('Države ponesrečencev')
axis.set_title('Države ponesrečencev')

# modificiramo podatke za prikaz (omogočimo prikaz velikih podatkov s prelomom v grafu)
compress = 3278
countries_cond_mod = [x for x in countries_cond]
countries_cond_mod[0] = (countries_cond[0][0], countries_cond[0][1] - compress)

bar_len = [b for a, b in countries_cond_mod]
bar_pos = [x for x in range(threshold_cond + 1)][::-1]
bar_label = [country for country, num in countries_cond]
bar_colors = ["#A05B41", "#DD8A5D"]

rects = axis.barh(bar_pos, bar_len, align='center', height=0.75, tick_label=bar_label, color=bar_colors, edgecolor='k')

# črte
axis.xaxis.grid(True, color='black', which='major', alpha=.3)
x_ticks = [x for x in range(0, 399, 50)]
axis.set_xticks(x_ticks + [3700 - compress, 3750 - compress, 3800 - compress])
axis.set_xticklabels(str(x) for x in x_ticks + [3700, 3750, 3800])

# tanjše črte
for k in range(25, 400, 50):
    axis.axvline(k, color='black', alpha=.15, linewidth=.8)

for k in range(3725 - compress, 3800 - compress, 50):
    axis.axvline(k, color='black', alpha=.15, linewidth=.8)

# številke v grafu
rect_labels = []
for i, rect in enumerate(rects):
    width = int(rect.get_width())
    text = '{:d}'.format(countries_cond[i][1])
    yloc = rect.get_y() + rect.get_height() / 2
    label = axis.annotate(text, xy=(width, yloc), xytext=(10, 0), 
                          textcoords='offset points', ha='left', va='center', color='black')
    rect_labels.append(label)

# črta preloma (breakpoint)
bp = 399
axis.plot([bp, bp], [14.6, 15.4], lw=16, color="#FFFFFF")
axis.plot([bp-6, bp-6], [14.3, 15.7], lw=2, color="#000000")
axis.plot([bp+6, bp+6], [14.3, 15.7], lw=2, color="#000000")

axis.set_xlabel("Število ponesrečencev")
axis.set_xlim(right=540);

# %% [markdown]
# Vidimo, da je največ ponesrečencev iz Slovenije, kar je pričakovano, saj so bili podatki zbrani v Sloveniji in na Slovenskih smučiščih.
#
# Zatem sledi Hrvaška. Glede na pozicijo naših smučišč bi mogoče pričakovali večje število ponesrečencev iz Italije ali Avstrije, a so podatki vseeno smiselni. V Italiji in Avstriji je veliko smučišč, na Hrvaškem pa jih skoraj ni - zato se Hrvati odločajo obiskovati smučišča v Sloveniji, kjer pa se tudi bolj pogosto poškodujejo.
#
# Zanimivo je tudi relativno veliko število poškodovancev iz Anglije. Zanimivo bi bilo izvedeti, ali je to zaradi tega, ker Angleži pogosto hodijo smučat v Slovenijo, ali pa so le bolj dovzetni za poškodbe.
#
# Italija in Avstrija sta kljub geografski bližini našim smučiščem predstavljeni v relativno manjšem številu - verjetno njihovi državljani smučajo doma, mogoče pa so zelo dobri pri izogibanju nesreč na smučiščih.

# %% [markdown]
# ### Korak 6: odločitveno drevo - resnost poškodbe
#
# Zgradili bomo odločitveno drevo, s katerim bomo glede na atribute poskušali predvideti, ali je poškodba lažja ali hujša.

# %%
# priprava podatkov

tab_tree = []
for entry in tab:
    # datum
    datum = entry[tg("datum")]
    if len(datum) < 10:
        continue
    dan_teden = ["ponedeljek", "torek", "sreda", "cetrtek", "petek", "sobota", "nedelja"][date_to_weekday(datum)]
    # poškodba
    poskodba_raw = entry[tg("poskodba")]
    if not (2 <= poskodba_raw <= 4):
        continue
    poskodba = map_poskodbe[poskodba_raw]
    if poskodba == "posebno huda":
        poskodba = "hujša"
    # čas
    cas = entry[tg("cas")]
    if len(cas) < 5:
        continue
    ura = int(cas[0:2])
    cas = "ponoci"
    if 8 <= ura < 12:
        cas = "dopoldne"
    elif 12 <= ura < 17:
        cas = "popoldne"
    # vreme
    vreme_raw = entry[tg("vreme")]
    if len(vreme_raw) < 3:
        continue
    vreme = "soncno"
    if vreme_raw in ["1 Sonèno", "jasno", "1 jasno", "3 rahlo oblaèno"]:
        vreme = "soncno"
    elif vreme_raw in ["2 Oblaèno", "5 oblaèno", "4 pretežno oblaèno", "2 delno ali zmerno oblaèno", "oblaèno", "pretežno oblaèno"]:
        vreme = "oblacno"
    elif vreme_raw in ["3 Dež", "5 Sneg"]:
        vreme = "padavine"
    elif vreme_raw in ["megla", "6 Megla"]:
        vreme = "megla"
    elif vreme_raw == "7 Veter":
        vreme = "veter"
    # ravnanje
    ravnanje_raw = entry[tg("ravnanje")]
    if len(ravnanje_raw) < 3:
        continue
    ravnanje = "ravnanje - drugo"
    if ravnanje_raw in ["1 je padel po lastni krivdi", "2 je padel", "Drugo PADEC", "je padel po lastni krivdi"]:
        ravnanje = "padec"
    elif ravnanje_raw == "Pomanjkljivo smuèarsko znanje":
        ravnanje = "pomanjkljivo znanje"
    elif ravnanje_raw == "Hitrost":
        ravnanje = "hitrost"
    elif ravnanje_raw == "Utrujenost":
        ravnanje = "utrujenost"
    elif ravnanje_raw == "15 je smuèal na zakolièeni progi":
        ravnanje = "smučanje na zakoličeni progi"
    elif ravnanje_raw in ["22 se je zaletel", "8 je naletel", "Drugo TRK"]:
        ravnanje = "se je zaletel"
    elif ravnanje_raw == "Drugo ZDRS":
        ravnanje = "zdrs"
    elif ravnanje_raw == "Odpeta smuèka/deska":
        ravnanje = "odpeta smucka/deska"
    elif ravnanje_raw == "Neupoštevanje pravil o redu in varnosti na smuèišèu":
        ravnanje = "neupostevanje navodil"
    elif ravnanje_raw in ["Skok", "12 je skoèil (terenski skok)"]:
        ravnanje = "skok"
    elif ravnanje_raw == "Neprimerna fizièna pripravljenost":
        ravnanje = "neprimerna fizicna pripravljenost"
    elif ravnanje_raw == "10 se je ustavljal z zavojem (L/D)":
        ravnanje = "ustavljanje z zavojem"
    #zvrst
    zvrst_raw = entry[tg("zvrst")]
    zvrst = "ni podatka/drugo"
    if zvrst_raw == 1:
        zvrst = "smucanje"
    elif zvrst_raw == 2:
        zvrst = "deskanje"
    elif zvrst_raw == 3:
        zvrst = "sankanje"
    # zapis v tabelo
    podatki = (dan_teden, cas, zvrst, vreme, ravnanje, poskodba)
    tab_tree.append(podatki)
# izpis za tabelo (markup)
#print("\n".join([" | ".join(line) for line in tab_tree[:12]]))
#print("...")
#print("\n".join([" | ".join(line) for line in tab_tree[len(tab_tree)-9:]]))

# %%
# odločitveno drevo

# https://scikit-learn.org/stable/modules/tree.html

from sklearn import tree
import pandas as pd

def class_to_seq(sequence):
    seq_map = []
    seq = []
    for s in sequence:
        if s in seq_map:
            seq.append(seq_map.index(s))
        else:
            seq_map.append(s)
            seq.append(seq_map.index(s))
    return seq, seq_map

def to_onehot(nums, maps):
    out = []
    for n, m in zip(nums, maps):
        new = [0] * len(m)
        new[n] = 1
        out += new
    return out

seq_dan      = [x[0] for x in tab_tree]
seq_cas      = [x[1] for x in tab_tree]
seq_zvrst    = [x[2] for x in tab_tree]
seq_vreme    = [x[3] for x in tab_tree]
seq_ravnanje = [x[4] for x in tab_tree]
seq_poskodba = [x[5] for x in tab_tree]

s_dan,      m_dan      = class_to_seq(seq_dan)
s_cas,      m_cas      = class_to_seq(seq_cas)
s_zvrst,    m_zvrst    = class_to_seq(seq_zvrst)
s_vreme,    m_vreme    = class_to_seq(seq_vreme)
s_ravnanje, m_ravnanje = class_to_seq(seq_ravnanje)
s_poskodba, m_poskodba = class_to_seq(seq_poskodba)

atributi = [(s_dan[i], s_cas[i], s_zvrst[i], s_vreme[i], s_ravnanje[i]) for i in range(len(s_dan))]
ciljni = [s_poskodba[i] for i in range(len(s_poskodba))]

maps = [m_dan, m_cas, m_zvrst, m_vreme, m_ravnanje]
atributi_oh = [to_onehot([s_dan[i], s_cas[i], s_zvrst[i], s_vreme[i], s_ravnanje[i]], maps) for i in range(len(s_dan))]

ciljni_oh = [to_onehot([s_poskodba[i]], [m_poskodba]) for i in range(len(s_poskodba))]

clf = tree.DecisionTreeClassifier(max_depth=4, min_weight_fraction_leaf=0.12)
clf = clf.fit(atributi_oh, ciljni)

# preizkusimo (na učnih podatkih)

hit_map = [clf.predict([atributi_oh[i]]) == ciljni[i] for i in range(len(atributi))]
hit_rate = sum(x[0] for x in hit_map) / len(hit_map)

f_names = m_dan + m_cas + m_zvrst + m_vreme + m_ravnanje
fig, axis = plt.subplots(figsize=(17, 12))
tree.plot_tree(clf, max_depth=3, fontsize=10, feature_names=f_names, proportion=True);

print("hit rate:", hit_rate)
# Out:
# hit rate: 0.9436681222707424

# %% [markdown]
# Zgoraj vidimo odločitveno drevo, ki poskuša ugotoviti resnost poškodbe glede na določene atribute. Bolj uporabno bi bilo sicer drevo, ki nam pove, katere okoliščine najbolj pripomorejo k nastanku poškodb, a vendar takih podatkov nimamo (seveda ne beležimo ne-nesreč). To odločitveno drevo pa nam še vseeno zadostuje - če se že poškodujemo, je bolje, da je poškodba lažja kot pa hujša. Lahko tudi sklepamo, da situacije, ki povzročajo večji delež lažjih poškodb, povzročajo tudi manj poškodb v splošnem.
#
# Zaradi tega, ker je velik delež vseh poškodb lažjih (94.4%), je težko sestaviti drevo, ki bi za določene atribute predvidel, da bo prišlo do hujše poškodbe - a nam vseeno da uporabne podatke, saj so situacije, kjer je delež hujših poškodb manjši, bolj varne.
#
# Iz korena grafa lahko razberemo, da pri padcih pride do hujših poškodb v večji meri kot pa pri drugih načinih obnašanja med nesrečo. Iz obeh otrok lahko razberemo, da je jasno oz. sončno vreme bolj varno od oblačnega. Iz njunih otrok pa lahko glede na čas dneva ugotovimo, da prihaja do hujših poškodb bolj pogosto dopoldne.
